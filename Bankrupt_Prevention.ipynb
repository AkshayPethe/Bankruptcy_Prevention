# %% [markdown]
# **Attribute Information**
#
# - Y - Bankrupt: Class label
# - X-1 - ROA(C) before interest and depreciation before interest: Return On Total Assets(C)
# - X2 - ROA(A) before interest and % after tax: Return On Total Assets(A)
# - X3 - ROA(B) before interest and depreciation after tax: Return On Total Assets(B)
# - X4 - Operating Gross Margin: Gross Profit/Net Sales
# - X5 - Realized Sales Gross Margin: Realized Gross Profit/Net Sales
# - X6 - Operating Profit Rate: Operating Income/Net Sales
# - X7 - Pre-tax net Interest Rate: Pre-Tax Income/Net Sales
# - X8 - After-tax net Interest Rate: Net Income/Net Sales
# - X9 - Non-industry income and expenditure/revenue: Net Non-operating Income Ratio
# - X10 - Continuous interest rate (after tax): Net Income-Exclude Disposal Gain or Loss/Net Sales
# - X11 - Operating Expense Rate: Operating Expenses/Net Sales
# - X12 - Research and development expense rate: (Research and Development Expenses)/Net Sales
# - X13 - Cash flow rate: Cash Flow from Operating/Current Liabilities
# - X14 - Interest-bearing debt interest rate: Interest-bearing Debt/Equity
# - X15 - Tax rate (A): Effective Tax Rate
# - X16 - Net Value Per Share (B): Book Value Per Share(B)
# - X17 - Net Value Per Share (A): Book Value Per Share(A)
# - X18 - Net Value Per Share (C): Book Value Per Share(C)
# - X19 - Persistent EPS in the Last Four Seasons: EPS-Net Income
# - X20 - Cash Flow Per Share
# - X21 - Revenue Per Share (Yuan ¥): Sales Per Share
# - X22 - Operating Profit Per Share (Yuan ¥): Operating Income Per Share
# - X23 - Per Share Net profit before tax (Yuan ¥): Pretax Income Per Share
# - X24 - Realized Sales Gross Profit Growth Rate
# - X25 - Operating Profit Growth Rate: Operating Income Growth
# - X26 - After-tax Net Profit Growth Rate: Net Income Growth
# - X27 - Regular Net Profit Growth Rate: Continuing Operating Income after Tax Growth
# - X28 - Continuous Net Profit Growth Rate: Net Income-Excluding Disposal Gain or Loss Growth
# - X29 - Total Asset Growth Rate: Total Asset Growth
# - X30 - Net Value Growth Rate: Total Equity Growth
# - X31 - Total Asset Return Growth Rate Ratio: Return on Total Asset Growth
# - X32 - Cash Reinvestment %: Cash Reinvestment Ratio
# - X33 - Current Ratio
# - X34 - Quick Ratio: Acid Test
# - X35 - Interest Expense Ratio: Interest Expenses/Total Revenue
# - X36 - Total debt/Total net worth: Total Liability/Equity Ratio
# - X37 - Debt ratio %: Liability/Total Assets
# - X38 - Net worth/Assets: Equity/Total Assets
# - X39 - Long-term fund suitability ratio (A): (Long-term Liability+Equity)/Fixed Assets
# - X40 - Borrowing dependency: Cost of Interest-bearing Debt
# - X41 - Contingent liabilities/Net worth: Contingent Liability/Equity
# - X42 - Operating profit/Paid-in capital: Operating Income/Capital
# - X43 - Net profit before tax/Paid-in capital: Pretax Income/Capital
# - X44 - Inventory and accounts receivable/Net value: (Inventory+Accounts Receivables)/Equity
# - X45 - Total Asset Turnover
# - X46 - Accounts Receivable Turnover
# - X47 - Average Collection Days: Days Receivable Outstanding
# - X48 - Inventory Turnover Rate (times)
# - X49 - Fixed Assets Turnover Frequency
# - X50 - Net Worth Turnover Rate (times): Equity Turnover
# - X51 - Revenue per person: Sales Per Employee
# - X52 - Operating profit per person: Operation Income Per Employee
# - X53 - Allocation rate per person: Fixed Assets Per Employee
# - X54 - Working Capital to Total Assets
# - X55 - Quick Assets/Total Assets
# - X56 - Current Assets/Total Assets
# - X57 - Cash/Total Assets
# - X58 - Quick Assets/Current Liability
# - X59 - Cash/Current Liability
# - X60 - Current Liability to Assets
# - X61 - Operating Funds to Liability
# - X62 - Inventory/Working Capital
# - X63 - Inventory/Current Liability
# - X64 - Current Liabilities/Liability
# - X65 - Working Capital/Equity
# - X66 - Current Liabilities/Equity
# - X67 - Long-term Liability to Current Assets
# - X68 - Retained Earnings to Total Assets
# - X69 - Total income/Total expense
# - X70 - Total expense/Assets
# - X71 - Current Asset Turnover Rate: Current Assets to Sales
# - X72 - Quick Asset Turnover Rate: Quick Assets to Sales
# - X73 - Working capitcal Turnover Rate: Working Capital to Sales
# - X74 - Cash Turnover Rate: Cash to Sales
# - X75 - Cash Flow to Sales
# - X76 - Fixed Assets to Assets
# - X77 - Current Liability to Liability
# - X78 - Current Liability to Equity
# - X79 - Equity to Long-term Liability
# - X80 - Cash Flow to Total Assets
# - X81 - Cash Flow to Liability
# - X82 - CFO to Assets
# - X83 - Cash Flow to Equity
# - X84 - Current Liability to Current Assets
# - X85 - Liability-Assets Flag: 1 if Total Liability exceeds Total Assets, 0 otherwise
# - X86 - Net Income to Total Assets
# - X87 - Total assets to GNP price
# - X88 - No-credit Interval
# - X89 - Gross Profit to Sales
# - X90 - Net Income to Stockholder's Equity
# - X91 - Liability to Equity
# - X92 - Degree of Financial Leverage (DFL)
# - X93 - Interest Coverage Ratio (Interest expense to EBIT)
# - X94 - Net Income Flag: 1 if Net Income is Negative for the last two years, 0 otherwise
# - X95 - Equity to Liability

# %% [markdown]
# **Altman Z-Score Ratios:**
#
# - X1: Return on Total Assets (ROA)
# - X2: Retained Earnings to Total Assets
# - X3: Earnings Before Interest and Taxes (EBIT) to Total Assets
# - X4: Market Value of Equity to Book Value of Total Liabilities
# - X5: Sales to Total Assets
# - The Altman Z-Score combines these ratios to create a single score that assesses the likelihood of bankruptcy.
#
# **Solvency and Debt Ratios:**
#
# - Debt-to-Equity Ratio
# - Debt Ratio
# - Interest Coverage Ratio
# - Current Ratio
# - Quick Ratio
# - Cash Flow to Total Debt
# - These ratios help gauge a company's ability to meet its financial obligations and manage debt.
#
# **Profitability and Efficiency Ratios:**
#
# - Operating Profit Margin
# - Net Profit Margin
# - Gross Profit Margin
# - Return on Assets (ROA)
# - Return on Equity (ROE)
# - Asset Turnover Ratio
# - Profitability and efficiency ratios provide insights into how effectively a company is generating profits and utilizing its assets.
#
# **Cash Flow Ratios:**
#
# - Cash Flow to Total Assets
# - Cash Flow to Equity
# - Operating Cash Flow to Total Debt
# - Cash Flow to Operating Income
# - Cash flow ratios indicate a company's ability to generate cash from its operations.
#
# **Liquidity Ratios:**
#
# - Cash Ratio
# - Liquidity ratios assess a company's short-term ability to cover its obligations.
#
# **Market Ratios:**
#
# - Price-to-Earnings (P/E) Ratio
# - Price-to-Book (P/B) Ratio

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    Bankrupt   ROA(C) before interest and depreciation before interest  \
# 0         1                                           0.370594
# 1         1                                           0.464291
# 2         1                                           0.426071
# 3         1                                           0.399844
# 4         1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
df.columns
# Out:
# Index(['Bankrupt', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %% [markdown]
# #### Checking Null Values

# %%
null_col = []
for col in df.columns:
    if df[col].isnull().sum() > 0:
        null_col.append(col)
print(null_col)
# Out:
# []

# %% [markdown]
# - No Null Value Detected

# %% [markdown]
# ** Analysed Points**
# - First three column same ratio just a data for three different share we can eliminate the any two of them.
# - Operating Gross Margin and Realized Sales Gross Margin are highly collinear.One can stay most likely Realized Sales Gross  Margin as its a profit after deducting the Cost of Goods like former and Adjustments like discount,allowance,returns.
# - After Column name analysis some of the feature ratios are directly or inversly proportional to each other.
# - Like Current Liability to Assets and Current Ratio which is Current Assets to Current Liabilities and etc.
# - ' Net Value Per Share (A)' and ' Net Value Per Share (B)' are high collinear to each other.

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
sns.scatterplot(data=df, x=' ROA(C) before interest and depreciation before interest', y=' ROA(A) before interest and % after tax',
                hue='Bankrupt', ax=ax[0])
sns.scatterplot(data=df, x=' Operating Gross Margin', y=' Realized Sales Gross Margin',
                hue='Bankrupt', ax=ax[1])
sns.scatterplot(data=df, x=' Net Value Per Share (A)', y=' Net Value Per Share (B)',
                hue='Bankrupt', ax=ax[2])
# Out:
# <Axes: xlabel=' Net Value Per Share (A)', ylabel=' Net Value Per Share (B)'>

# %% [markdown]
# - No remove such Column we can perform Multicollinearity

# %%
import statsmodels.api as sm
import scipy.stats as stats

model = sm.OLS(y, sm.add_constant(X)).fit()
residuals = model.resid

# Residual Analysis: Residual vs. Fitted Values Plot
plt.figure(figsize=(10, 6))
plt.scatter(model.fittedvalues, residuals)
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residual vs. Fitted Values Plot')
plt.axhline(y=0, color='r', linestyle='--')
plt.show()
print("*"*64)

print("Rainbow Test for Linearity\n")
rainbow_statistic, rainbow_p_value = sm.stats.diagnostic.linear_rainbow(model)
print("Rainbow Test Statistic:", rainbow_statistic)
print("Rainbow Test p-value:", rainbow_p_value)
print("*"*64)

print('Shapiro-Wilk Test for Normality\n')
shapiro_test_statistic, shapiro_p_value = stats.shapiro(residuals)
print("Shapiro-Wilk Test Statistic:", shapiro_test_statistic)
print("Shapiro-Wilk Test p-value:", shapiro_p_value)
print("*"*64)

print('Heteroscedasticity Test: Breusch-Pagan Test\n')
bp_test_statistic, bp_p_value, _, _ = sm.stats.diagnostic.het_breuschpagan(residuals, X)
print("Breusch-Pagan Test Statistic:", bp_test_statistic)
print("Breusch-Pagan Test p-value:", bp_p_value)
print("*"*64)
# Out:
# ****************************************************************
# Rainbow Test for Linearity
#
# Rainbow Test Statistic: 0.9670300417666937
# Rainbow Test p-value: 0.8348491437906327
# ****************************************************************
# Shapiro-Wilk Test for Normality
#
# Shapiro-Wilk Test Statistic: 0.4832284450531006
# Shapiro-Wilk Test p-value: 0.0
# ****************************************************************
# Heteroscedasticity Test: Breusch-Pagan Test
#
# Breusch-Pagan Test Statistic: 941.505187313181
# Breusch-Pagan Test p-value: 6.215533149752573e-150
# ****************************************************************

# %% [markdown]
# #### The residuals shows a pattern where they increase or decrease as the plotted values change, it could indicate that the linear model is not capturing the true relationship between the variables.
#
# **Rainbow Test for Linearity**
# - The p-value is relatively high (0.8348), which suggests that there is no significant evidence to reject the null hypothesis of linearity.
#
# **Shapiro-Wilk Test for Normality**
# - A low p-value (in this case, close to zero) indicates that the null hypothesis of normality is rejected. The data is likely not normally distributed.
#
# **Breusch-Pagan Test:Heteroscedasticity**
# - A low p-value (close to zero) indicates evidence against the null hypothesis of homoscedasticity (constant variance). In this case, the very low p-value suggests the presence of heteroscedasticity.
#
#
# #### So we can say the data has Non Linear relationship.

# %% [markdown]
# ### Multicollinearity Check

# %%
plt.figure(figsize = (15,15))
corr_matrix = df.corr(method = 'spearman').round(2)
lower= corr_matrix.where(np.tril(np.ones(corr_matrix.shape),k =-1).astype(bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(lower_after,cmap = cmap)
# Out:
# <Axes: >

# %%
pos_corr =[col for col in lower.columns if any(lower[col] >= 0.9)]
neg_corr = [col for col in lower.columns if any(lower[col] <= -0.9)]

# %%
len(pos_corr)+len(neg_corr)
# Out:
# 47

# %%
print("Spearman Coeff ")
print("*"*64)
print("Postive Correlation (Spearman):",pos_corr)
print("*"*64)
print("Negative Correlation (Spearman):",neg_corr)
# Out:
# Spearman Coeff
# ****************************************************************
# ...

# %%
data = df[feature]

# %%
X = data.drop('Bankrupt',axis = 1)
y = data['Bankrupt']

# %% [markdown]
# #### As data is non linear we can use Mutual Info Classif rather than RFE which has linearity assumptions

# %% [markdown]
# #### Feature Selection By Mutual_info_classif

# %%
from sklearn.feature_selection import mutual_info_classif,SelectKBest

mi_score= mutual_info_classif(X,y)
mi_scores = pd.DataFrame({'Features': X.columns ,"MI_Score":mi_score})
mi_scores = mi_scores.sort_values(by = "MI_Score",ascending = False)
plt.figure(figsize = (18,6))
sns.barplot(x = mi_scores['Features'],y = mi_scores["MI_Score"])
plt.xticks(rotation = 90)
plt.show()

# %%
k = 20
indep_var = [col for col in df.columns if col !="Bankrupt"]
selector = SelectKBest(score_func = mutual_info_classif,k  = k)
select_features = selector.fit_transform(X,y)

feature_mask = selector.get_support()
feature_name = [indep_var[i] for i,mask in enumerate(feature_mask) if mask]

print(f"Top {k} Feature are \n{feature_name}")
plt.figure(figsize = (18,6))
sns.barplot(x = feature_name,y = mi_scores["MI_Score"][:20])
plt.xticks(rotation = 90)
plt.show()
# Out:
# Top 20 Feature are
# [' ROA(C) before interest and depreciation before interest', ' ROA(A) before interest and % after tax', ' After-tax net Interest Rate', ' Revenue Per Share (Yuan ¥)', ' Operating Profit Per Share (Yuan ¥)', ' Per Share Net profit before tax (Yuan ¥)', ' Realized Sales Gross Profit Growth Rate', ' Regular Net Profit Growth Rate', ' Continuous Net Profit Growth Rate', ' Long-term fund suitability ratio (A)', ' Net profit before tax/Paid-in capital', ' Revenue per person', ' Operating profit per person', ' Working Capital/Equity', ' Long-term Liability to Current Assets', ' Current Asset Turnover Rate', ' Quick Asset Turnover Rate', ' Working capitcal Turnover Rate', ' Cash Turnover Rate', ' Fixed Assets to Assets']

# %%
df1 = df[feature_name]

# %%
sns.displot(x =' ROA(C) before interest and depreciation before interest',data = df,hue = 'Bankrupt',kde = True)

# %%
df1.columns
# Out:
# Index([' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' After-tax net Interest Rate', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
#        ' Realized Sales Gross Profit Growth Rate',
#        ' Regular Net Profit Growth Rate', ' Continuous Net Profit Growth Rate',
#        ' Long-term fund suitability ratio (A)',
#        ' Net profit before tax/Paid-in capital', ' Revenue per person',
#        ' Operating profit per person', ' Working Capital/Equity',
#        ' Long-term Liability to Current Assets',
#        ' Current Asset Turnover Rate', ' Quick Asset Turnover Rate',
#        ' Working capitcal Turnover Rate', ' Cash Turnover Rate',
#        ' Fixed Assets to Assets'],
#       dtype='object')

# %%
sns.displot(x =' ROA(A) before interest and % after tax',data = df,hue = 'Bankrupt',kde = True)

# %%
sns.scatterplot(x =' After-tax net Interest Rate',data = df,hue = 'Bankrupt',kde = True)
